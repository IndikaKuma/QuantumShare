# %%
# %status
# Out:
# {'status': 'healthy',
#  'startTime': 'Thu Jun 30 11:53:17 UTC 2022',
#  'dbEngineVersion': '1.1.1.0.R3',
#  'role': 'writer',
#  'dfeQueryEngine': 'viaQueryHint',
#  'gremlin': {'version': 'tinkerpop-3.5.2'},
#  'sparql': {'version': 'sparql-1.1'},
#  'opencypher': {'version': 'Neptune-9.0.20190305-1.0'},
#  'labMode': {'ObjectIndex': 'disabled',
#   'ReadWriteConflictDetection': 'enabled'},
#  'features': {'ResultCache': {'status': 'disabled'},
#   'IAMAuthentication': 'disabled',
#   'Streams': 'disabled',
#   'AuditLog': 'disabled'},
#  'settings': {'clusterQueryTimeoutInMs': '120000'}}

# %%
from SPARQLWrapper import SPARQLWrapper, POST
from PlanQK_extraction_v4 import *
from QAZ_extraction_v5 import *
import ast

# %% [markdown]
# ### Data ingestion

# %%
url_qaz = "https://raw.githubusercontent.com/MIBbrandon/stephenjordan.github.io/master/src/storage/"
url_planqk = "https://raw.githubusercontent.com/PlanQK/semantic-services/master/extracted%20knowledge/"

# %%
data_qaz = [triples_algorithms(url_qaz), triples_publications(url_qaz)]
data_planqk = [triples_applicationareas(url_planqk), triples_software(url_planqk), triples_problems(url_planqk)]

# %%
def check_input(o):
    prefixes = ["cs:", "dc:","mls:","muo:","org:","owl:","rdf:","xml:","xsd:","rdfs:","terms:","parameter:","Publication:",
                "quantumshare:","Implementation:","ProblemExecution:","QuantumAlgorithm:","cpannotationschema:"]
    if type(o) == int:
        return o
    elif any(i in o for i in prefixes): 
        return o
    else:
        o = f'"{o}"'
        return o

# %%
def ingestion(triplet):
    triple = triplet
    triple['s'] = check_input(triple['s'])
    triple['o'] = check_input(triple['o']) #prevents bad queries for labels, strings, and integers
    print(triple)
    sparql = SPARQLWrapper("https://database-1-jm.cluster-csbkotxlmqjb.eu-west-1.neptune.amazonaws.com:8182/sparql")
    sparql.setMethod(POST)

    sparql.setQuery("""PREFIX cs: <http://mklab.iti.gr/pericles/ComputerSystem_ODP#> 
                PREFIX dc: <http://purl.org/dc/elements/1.1/> 
                PREFIX dul: <http://www.ontologydesignpatterns.org/ont/dul/DUL.owl#> 
                PREFIX mls: <http://www.w3.org/ns/mls/cp#> 
                PREFIX muo: <http://elite.polito.it/ontologies/muo-vocab.owl#> 
                PREFIX org: <http://www.w3.org/ns/org#> 
                PREFIX owl: <http://www.w3.org/2002/07/owl#> 
                PREFIX rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> 
                PREFIX xml: <http://www.w3.org/XML/1998/namespace> 
                PREFIX xsd: <http://www.w3.org/2001/XMLSchema#> 
                PREFIX rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
                PREFIX terms: <http://purl.org/dc/terms/> 
                PREFIX parameter: <http://www.semanticweb.org/20173656/ontologies/2022/5/Parameter#> 
                PREFIX Publication: <http://www.semanticweb.org/20173656/ontologies/2022/5/Publication#> 
                PREFIX quantumshare: <http://www.semanticweb.org/20173656/ontologies/2022/5/QuantumShare#> 
                PREFIX Implementation: <http://www.semanticweb.org/20173656/ontologies/2022/5/QuantumImplementation#> 
                PREFIX ProblemExecution: <http://www.semanticweb.org/20173656/ontologies/2022/5/ProblemExecution#> 
                PREFIX QuantumAlgorithm: <http://www.semanticweb.org/20173656/ontologies/2022/5/QuantumAlgorithm#> 
                PREFIX cpannotationschema: <http://www.ontologydesignpatterns.org/schemas/cpannotationschema.owl#> 
                INSERT DATA {{{s} {p} {o}}}""".format(s=triple['s'], p=triple['p'], o=triple['o'])
    )

    results = sparql.query()
    print(results.response.read())

# %% [markdown]
# #### Github Repositories

# %%
for function in data_planqk:
    for i in function:
        ingestion(i)
# Out:
# {'s': 'quantumshare:Engineering_Science', 'p': 'rdfs:subClassOf', 'o': 'ProblemExecution:Application_Area'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Engineering_Science', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 9\n}\n]'
# {'s': 'quantumshare:Civil_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 1,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Civil_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Architecture', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Civil_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Architecture', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 2,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 5\n}\n]'
# {'s': 'quantumshare:Agricultural_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Civil_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Agricultural_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Construction_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Civil_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Construction_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Building_Informatics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Building_Informatics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Geotechnics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Geotechnics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Transportation_Planning', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Transportation_Planning', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Materials_Science', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Materials_Science', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Materials_Structuring_and_Functionalisation', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Materials_Structuring_and_Functionalisation', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Microstructural_Mechanical_Properties_of_Materials', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 5\n}\n]'
# {'s': 'quantumshare:Microstructural_Mechanical_Properties_of_Materials', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Polymer_Research', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Polymer_Research', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Polymer_Physics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Polymer_Research'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Polymer_Physics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Materials_Informatics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Materials_Informatics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Nanotechnology', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Nanotechnology', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Urban_Planning', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Urban_Planning', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Building_Engineering_Physics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Building_Engineering_Physics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Structural_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Structural_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Landscape_Planning', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Landscape_Planning', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Hydraulic_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Construction_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 4,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Hydraulic_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Energy_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Energy_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Thermal_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Energy_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Thermal_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Systems_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Systems_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Logistics_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Systems_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Logistics_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Measurement_Systems', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Systems_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Measurement_Systems', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:HumanMachine_Systems_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Systems_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:HumanMachine_Systems_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Ergonomics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Systems_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Ergonomics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Robotics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Systems_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Robotics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Microsystems', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Systems_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Microsystems', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Mechanical_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Mechanical_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Agricultural_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Mechanical_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Agricultural_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Mechanics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Mechanical_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Mechanics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 1,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Acoustics', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Mechanical_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Acoustics', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Process_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Process_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Mechanical_Process_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Process_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Mechanical_Process_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Technical_Chemistry', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Process_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Technical_Chemistry', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Chemical_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Process_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Chemical_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Thermomechanical_Processing', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Process_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Thermomechanical_Processing', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Maritime_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Maritime_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Electrical_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Electrical_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Computational_Neuroscience', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Electrical_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Computational_Neuroscience', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Telecommunication_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Electrical_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Telecommunication_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Component_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Electrical_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Component_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Power_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Electrical_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Power_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Bioengineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Bioengineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Synthetic_Biology', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Bioengineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Synthetic_Biology', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Materials_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Materials_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Mechanical_Behaviour_of_Construction_Materials', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Mechanical_Behaviour_of_Construction_Materials', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Composite_Materials', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Composite_Materials', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Sintering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Sintering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Coating_and_Surface_Technology', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Coating_and_Surface_Technology', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Metallurgy', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Materials_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Metallurgy', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Industrial_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Industrial_Engineering', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Safety_Science', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Industrial_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Safety_Science', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Production_Technology', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Industrial_Engineering'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Production_Technology', 'p': 'rdfs:comment', 'o': '"Subclasses of the concept Application Area are reused from FAIRsharing Subject Ontology (SRAO, licensed under CC BY 4.0)."'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Aerospace_Engineering', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Engineering_Science'}
# ...
# {'s': 'quantumshare:Traveling_Salesman_Problem', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Traveling_Salesman_Problem', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Shortest_Path_Problem', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Shortest_Path_Problem', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Network_Flow_Problem', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Network_Flow_Problem', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:NowhereZero_Flow', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Network_Flow_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:NowhereZero_Flow', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:MinimumCost_Flow', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Network_Flow_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:MinimumCost_Flow', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Maximum_Flow', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Network_Flow_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Maximum_Flow', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:MultiCommodity_Flow', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Network_Flow_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 30,\n    "elapsedMillis" : 30,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 30\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 31\n}\n]'
# {'s': 'quantumshare:MultiCommodity_Flow', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Vertex_Cover', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Vertex_Cover', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Graph_Coloring_Problem', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Graph_Coloring_Problem', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Edge_Coloring', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Coloring_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Edge_Coloring', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Face_Coloring', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Coloring_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Face_Coloring', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Vertex_Coloring', 'p': 'rdfs:subClassOf', 'o': 'quantumshare:Graph_Coloring_Problem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Vertex_Coloring', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Randomized_Search', 'p': 'rdfs:subClassOf', 'o': 'ProblemExecution:SearchProblem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Randomized_Search', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Heuristic_Search', 'p': 'rdfs:subClassOf', 'o': 'ProblemExecution:SearchProblem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Heuristic_Search', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Discrete_Space_Search', 'p': 'rdfs:subClassOf', 'o': 'ProblemExecution:SearchProblem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Discrete_Space_Search', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Search_With_Partial_Observations', 'p': 'rdfs:subClassOf', 'o': 'ProblemExecution:SearchProblem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Search_With_Partial_Observations', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Continuous_Space_Search', 'p': 'rdfs:subClassOf', 'o': 'ProblemExecution:SearchProblem'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Continuous_Space_Search', 'p': 'rdfs:comment', 'o': '"Inspiration: https://dl.acm.org/ccs and https://arxiv.org/corr/subjectclasses. The full CCS classification tree is freely available for educational and research purposes in HTML format. "'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'

# %% [markdown]
# #### Text files about publications

# %%
def txt_to_triples(path):
    with open(path) as f:
        triples = f.read().splitlines()
        triples = [ast.literal_eval(i) for i in triples]
    return triples

# %%
data_application = txt_to_triples('ExxonMobil_triples.txt')
data_implementation = txt_to_triples('Qiskit_triples.txt')

# %%
for i in data_implementation:
    ingestion(i)
# Out:
# {'s': 'quantumshare:Qiskit', 'p': 'rdfs:subClassOf', 'o': '"<http://www.semanticweb.org/20173656/ontologies/2022/4/QuantumComputingV2#Quantum_Implementation>"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 7\n}\n]'
# {'s': 'quantumshare:IBM', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Implementer'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit', 'p': 'Implementation:involvesOrganization', 'o': 'quantumshare:IBM'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit_Software', 'p': 'rdfs:subClassOf', 'o': 'cs:Software'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit', 'p': 'cs:usesSoftware', 'o': 'quantumshare:Qiskit_Software'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:First_Release', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Software_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:License', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Software_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Version', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Software_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Operating_System', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Software_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit_Software', 'p': 'dul:hasParameter', 'o': 'quantumshare:First_Release'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit_Software', 'p': 'dul:hasParameter', 'o': 'quantumshare:License'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit_Software', 'p': 'dul:hasParameter', 'o': 'quantumshare:Version'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Qiskit_Software', 'p': 'dul:hasParameter', 'o': 'quantumshare:Operating_System'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:First_Release', 'p': 'dul:hasParameterDataValue', 'o': '"0.1 on March 7, 2017"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:License', 'p': 'dul:hasParameterDataValue', 'o': '"Apache-2.0"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 20\n}\n]'
# {'s': 'quantumshare:Version', 'p': 'dul:hasParameterDataValue', 'o': '"0.5.4"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 18\n}\n]'
# {'s': 'quantumshare:Operating_System', 'p': 'dul:hasParameterDataValue', 'o': '"Mac"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 13\n}\n]'
# {'s': 'quantumshare:Operating_System', 'p': 'dul:hasParameterDataValue', 'o': '"Windows"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 1,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 11\n}\n]'
# {'s': 'quantumshare:Operating_System', 'p': 'dul:hasParameterDataValue', 'o': '"Linux"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit_Language', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Quantum_Programming_Language'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:OpenQASM', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Assembly_Language'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Python', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Syntax_Language'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:JavaScript', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Syntax_Language'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Swift', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Syntax_Language'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Qiskit_Language', 'p': 'cs:isCompatibleWith', 'o': 'quantumshare:Qiskit_Software'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:OpenQASM', 'p': 'cs:isCompatibleWith', 'o': 'quantumshare:Qiskit'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 5\n}\n]'
# {'s': 'quantumshare:Python', 'p': 'cs:isCompatibleWith', 'o': 'quantumshare:Qiskit'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:JavaScript', 'p': 'cs:isCompatibleWith', 'o': 'quantumshare:Qiskit'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 8\n}\n]'
# {'s': 'quantumshare:Swift', 'p': 'cs:isCompatibleWith', 'o': 'quantumshare:Qiskit'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Qiskit_SDK', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Software_Development_Kit'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Aqua', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Library'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Aqua', 'p': 'dul:isPartOf', 'o': 'quantumshare:Qiskit_SDK'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:IBMQX5', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Quantum_Processing_Unit'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit', 'p': 'cs:usesHardware', 'o': 'quantumshare:IBMQX5'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit_Software', 'p': 'cs:isCompatibleWith', 'o': 'quantumshare:IBMQX5'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:IBM', 'p': 'rdfs:subClassOf', 'o': 'Implementation:ResourceProvider'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:IBMQX5', 'p': 'Implementation:involvesOrganization', 'o': 'quantumshare:IBM'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Number_Of_Qubits_Offered', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Resource_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Min_Coherence_Time', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Resource_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Max_Coherence_Time', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Resource_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Single_Qubit_Gate_Fidelity', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Resource_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Multi_Qubit_Gate_Fidelity', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Resource_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:IBMQX5', 'p': 'dul:hasParameter', 'o': 'quantumshare:Number_Of_Qubits_Offered'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 5\n}\n]'
# {'s': 'quantumshare:Number_Of_Qubits_Offered', 'p': 'dul:hasParameterDataValue', 'o': '"16"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:IBMQX5', 'p': 'dul:hasParameter', 'o': 'quantumshare:Min_Coherence_Time'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Min_Coherence_Time', 'p': 'dul:hasParameterDataValue', 'o': '"31"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Min_Coherence_Time', 'p': 'dul:parametrizes', 'o': 'quantumshare:Duration'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Duration', 'p': 'muo:measuredIn', 'o': 'quantumshare:Microseconds'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:IBMQX5', 'p': 'dul:hasParameter', 'o': 'quantumshare:Max_Coherence_Time'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Max_Coherence_Time', 'p': 'dul:hasParameterDataValue', 'o': '"89"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Max_Coherence_Time', 'p': 'dul:parametrizes', 'o': 'quantumshare:Duration'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Duration', 'p': 'muo:measuredIn', 'o': 'quantumshare:Microseconds'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:IBMQX5', 'p': 'dul:hasParameter', 'o': 'quantumshare:Single_Qubit_Gate_Fidelity'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Single_Qubit_Gate_Fidelity', 'p': 'dul:hasParameterDataValue', 'o': '"99.5"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Single_Qubit_Gate_Fidelity', 'p': 'dul:parametrizes', 'o': 'quantumshare:Fraction'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Fraction', 'p': 'muo:measuredIn', 'o': 'quantumshare:Percentage'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 5\n}\n]'
# {'s': 'quantumshare:IBMQX5', 'p': 'dul:hasParameter', 'o': 'quantumshare:Multi_Qubit_Gate_Fidelity'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Multi_Qubit_Gate_Fidelity', 'p': 'dul:hasParameterDataValue', 'o': '"94.9"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Multi_Qubit_Gate_Fidelity', 'p': 'dul:parametrizes', 'o': 'quantumshare:Fraction'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 2\n}\n]'
# {'s': 'quantumshare:Fraction', 'p': 'muo:measuredIn', 'o': 'quantumshare:Percentage'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 1\n}\n]'
# {'s': 'quantumshare:Local_Unitrary_Simulator', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Local_Quantum_Simulator'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit', 'p': 'cs:usesHardware', 'o': 'quantumshare:Local_Unitrary_Simulator'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Qiskit_Software', 'p': 'cs:isCompatibleWith', 'o': 'quantumshare:Local_Unitrary_Simulator'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 1,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Local_Unitrary_Simulator', 'p': 'Implementation:involvesOrganization', 'o': 'quantumshare:IBM'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 1,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 6\n}\n]'
# {'s': 'quantumshare:Gate_Set', 'p': 'rdfs:subClassOf', 'o': 'Implementation:Resource_Property'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:Local_Unitrary_Simulator', 'p': 'dul:hasParameter', 'o': 'quantumshare:Gate_Set'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Gate_Set', 'p': 'dul:hasParameterDataValue', 'o': '"10"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Local_Unitrary_Simulator', 'p': 'dul:hasParameter', 'o': 'quantumshare:Number_Of_Qubits_Offered'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:Number_Of_Qubits_Offered', 'p': 'dul:hasParameterDataValue', 'o': '"10"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:432', 'p': 'dul:isAbout', 'o': 'quantumshare:QUBO_With_ADMM_Solver'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:432', 'p': 'rdfs:subClassOf', 'o': 'Publication:Publication'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:432', 'p': 'dul:hasParameter', 'o': 'quantumshare:authorsRyanLarose'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:authorsRyanLarose', 'p': 'rdfs:subClassOf', 'o': 'Publication:Metadata'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:authorsRyanLarose', 'p': 'dul:hasParameterDataValue', 'o': '"Ryan Larose"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:titleOverviewAndComparisonOfGateLevelQuantum', 'p': 'rdfs:subClassOf', 'o': 'Publication:Metadata'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 7\n}\n]'
# {'s': 'quantumshare:432', 'p': 'dul:hasParameter', 'o': 'quantumshare:titleOverviewAndComparisonOfGateLevelQuantum'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:titleOverviewAndComparisonOfGateLevelQuantum', 'p': 'dul:hasParameterDataValue', 'o': '"Overview and Comparison of Gate Level Quantum Software Platforms"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:links1022331q20190325130', 'p': 'rdfs:subClassOf', 'o': 'Publication:Metadata'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:432', 'p': 'dul:hasParameter', 'o': 'quantumshare:links1022331q20190325130'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
# {'s': 'quantumshare:links1022331q20190325130', 'p': 'dul:hasParameterDataValue', 'o': '"10.22331/q-2019-03-25-130"'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 4\n}\n]'
# {'s': 'quantumshare:QUBO_With_ADMM_Solver', 'p': 'dul:isPartOf', 'o': 'quantumshare:Qiskit'}
# b'[\n{\n    "type" : "UpdateEvent",\n    "totalElapsedMillis" : 0,\n    "elapsedMillis" : 0,\n    "connFlush" : 0,\n    "batchResolve" : 0,\n    "whereClause" : 0,\n    "deleteClause" : 0,\n    "insertClause" : 0\n},\n{\n    "type" : "Commit",\n    "totalElapsedMillis" : 3\n}\n]'
